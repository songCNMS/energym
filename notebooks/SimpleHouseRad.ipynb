# %% [markdown]
# # SimpleHouseRad notebook example

# %% [markdown]
# In this example, the usage of the model "SimpleHouseRad-v0" is demonstrated.

# %% [markdown]
# First, we import Energym and create the simulation environment by specifying the model, a weather file and the number of simulation days.

# %%
import sys
sys.path.insert(0, "/home/lesong/energym/")
import energym

weather = "CH_BS_Basel"
env = energym.make("SimpleHouseRad-v0", weather=weather, simulation_days=20)
# Out:
# the initial variables are {'u': 0.0}

# %% [markdown]
# The control inputs can be inspected using the `get_inputs_names()` method.

# %%
inputs = env.get_inputs_names()
print(inputs)
# Out:
# ['u']

# %% [markdown]
# To run the simulation, a number of steps is specified (here 288 steps per day for 10 days), a control input is specified and passed to the simulation model with the `step()` method. To generate some plots later on, we save all the outputs in lists.

# %%
from scipy import signal

steps = 288*10
out_list = []
# env.reset()
env.step(env.sample_random_action())
outputs = env.get_output()
controls = []
hour = 0
for i in range(steps):
    control = {}
    control['u'] = [0.5*(signal.square(0.1*i)+1.0)]
    controls +=[ {p:control[p][0] for p in control} ]
    outputs = env.step(control)
    _,hour,_,_ = env.get_date()
    out_list.append(outputs)
# Out:
# [OK] <JMIRuntime><value name="build_date">"Feb 24 2021"</value> <value name="build_time">"21:25:41"</value></JMIRuntime>
# [WARNING] <DivideByZero category="warning"><value name="exp">"exp.H / exp.m"</value>, <value name="val">"0.00000000000000E+00, 0.00000000000000E+00"</value></DivideByZero>
# [WARNING] <DivideByZero category="warning"><value name="exp">"(- heaPum.con.vol.dynBal.U) / (- heaPum.con.vol.dynBal.m)"</value>, <value name="val">"-0.00000000000000E+00, -0.00000000000000E+00"</value></DivideByZero>
# [WARNING]   <SingularJacobian category="warning">Singular Jacobian detected for <value name="block">"4"</value> at <value name="t">        0.0000000000000000E+00</value></SingularJacobian>
# [WARNING]   <SingularJacobian category="warning">Singular Jacobian detected for <value name="block">"5"</value> at <value name="t">        0.0000000000000000E+00</value></SingularJacobian>
# [WARNING]   <SingularJacobian category="warning">Singular Jacobian detected for <value name="block">"6"</value> at <value name="t">        0.0000000000000000E+00</value></SingularJacobian>
# [WARNING]   <SingularJacobian category="warning">Singular Jacobian detected for <value name="block">"7"</value> at <value name="t">        0.0000000000000000E+00</value></SingularJacobian>
# [WARNING]   <SingularJacobian category="warning">Singular Jacobian detected for <value name="block">"8"</value> at <value name="t">        0.0000000000000000E+00</value></SingularJacobian>
# [WARNING] <DivideByZeroInFunc category="warning"><value name="func">"Buildings.Fluid.BaseClasses.FlowModels.basicFlowFunction_m_flow"</value>, <value name="exp">"(m_flow_turbulent / k)"</value>, <value name="val">"0.00000000000000E+00, 0.00000000000000E+00"</value></DivideByZeroInFunc>
# [WARNING] <DivideByZeroInFunc category="warning"><value name="func">"Buildings.Fluid.BaseClasses.FlowModels.basicFlowFunction_m_flow"</value>, <value name="exp">"(m_flow_turbulent / k)"</value>, <value name="val">"0.00000000000000E+00, 0.00000000000000E+00"</value></DivideByZeroInFunc>
# [WARNING] <DivideByZeroInFunc category="warning"><value name="func">"Buildings.Fluid.BaseClasses.FlowModels.basicFlowFunction_m_flow"</value>, <value name="exp">"m_flow / m_flow_turbulent"</value>, <value name="val">"0.00000000000000E+00, 0.00000000000000E+00"</value></DivideByZeroInFunc>
# [WARNING] <DivideByZero category="warning"><value name="exp">"pumHeaPum.PToMed.u2 / pumHeaPum.etaHyd"</value>, <value name="val">"-NAN, 0.00000000000000E+00"</value></DivideByZero>
# [WARNING] <DivideByZero category="warning"><value name="exp">"(- heaPum.eva.vol.dynBal.U) / (- heaPum.eva.vol.dynBal.m)"</value>, <value name="val">"-0.00000000000000E+00, -0.00000000000000E+00"</value></DivideByZero>
# [WARNING]   <DivideByZero category="warning"><value name="exp">"1 / abs(heaPum.con.gai.k)"</value>, <value name="val">"1.00000000000000E+00, 0.00000000000000E+00"</value></DivideByZero>
# [WARNING]   <DivideByZero category="warning"><value name="exp">"heaPum.QEva_flow_internal / heaPum.eva.gai.k"</value>, <value name="val">"0.00000000000000E+00, 0.00000000000000E+00"</value></DivideByZero>
# [WARNING]   <DivideByZero category="warning"><value name="exp">"heaPum.QEva_flow / heaPum.eva.gai.k"</value>, <value name="val">"-NAN, 0.00000000000000E+00"</value></DivideByZero>
# [WARNING]   <DivideByZero category="warning"><value name="exp">"heaPum.QCon_flow_internal / heaPum.con.gai.k"</value>, <value name="val">"0.00000000000000E+00, 0.00000000000000E+00"</value></DivideByZero>
# [WARNING]   <DivideByZero category="warning"><value name="exp">"heaPum.QCon_flow / heaPum.con.gai.k"</value>, <value name="val">"-NAN, 0.00000000000000E+00"</value></DivideByZero>
# [WARNING]   <IllegalResidualOutput category="warning">The output is illegal in <value name="block">"11"</value>
# [WARNING]     <vector name="NaNResidualIndices" flags="residual_index">0, 1</vector>
# [WARNING]     <vector name="illegal_ivs">        0.0000000000000000E+00,         0.0000000000000000E+00</vector>
# [WARNING]     <vector name="illegal_residuals">                          -NAN,                            NAN</vector>
# [WARNING]   </IllegalResidualOutput>
# [ERROR]   <InitialEvaluation category="error">Residual function evaluation failed at initial point for <value name="block">"11"</value></InitialEvaluation>
# [WARNING]   <DivideByZero category="warning"><value name="exp">"heaPum.QEva_flow_internal / heaPum.eva.gai.k"</value>, <value name="val">"0.00000000000000E+00, 0.00000000000000E+00"</value></DivideByZero>
# [WARNING]   <DivideByZero category="warning"><value name="exp">"heaPum.QEva_flow / heaPum.eva.gai.k"</value>, <value name="val">"-NAN, 0.00000000000000E+00"</value></DivideByZero>
# [WARNING]   <DivideByZero category="warning"><value name="exp">"heaPum.QCon_flow_internal / heaPum.con.gai.k"</value>, <value name="val">"0.00000000000000E+00, 0.00000000000000E+00"</value></DivideByZero>
# [WARNING]   <DivideByZero category="warning"><value name="exp">"heaPum.QCon_flow / heaPum.con.gai.k"</value>, <value name="val">"-NAN, 0.00000000000000E+00"</value></DivideByZero>
# [WARNING]   <IllegalResidualOutput category="warning">The output is illegal in <value name="block">"11"</value>
# [WARNING]     <vector name="NaNResidualIndices" flags="residual_index">0, 1</vector>
# [WARNING]     <vector name="illegal_ivs">        0.0000000000000000E+00,         0.0000000000000000E+00</vector>
# [WARNING]     <vector name="illegal_residuals">                          -NAN,                            NAN</vector>
# [WARNING]   </IllegalResidualOutput>
# [ERROR]   <InitialEvaluation category="error">Jacobian evaluation failed at initial point for <value name="block">"11"</value></InitialEvaluation>
# [WARNING] <DivideByZero category="warning"><value name="exp">"(- vol.dynBal._der_mXi[1] + der(vol.dynBal.m) * vol.dynBal.medium.Xi[1]) / (- vol.dynBal.m)"</value>, <value name="val">"0.00000000000000E+00, -0.00000000000000E+00"</value></DivideByZero>
# [WARNING]   <SingularJacobian category="warning">Singular Jacobian detected for <value name="block">"10"</value> at <value name="t">        0.0000000000000000E+00</value></SingularJacobian>
# [ERROR]   <NaNOutput category="error">Not a number in block <value name="rhs" flags="index">0</value> from <value name="block">"10"</value></NaNOutput>
# [WARNING] <DivideByZero category="warning"><value name="exp">"(- vol.dynBal.m) / (- vol.V * 1.2 * (1.0 / 101325.0))"</value>, <value name="val">"-0.00000000000000E+00, -0.00000000000000E+00"</value></DivideByZero>
# [WARNING] <DivideByZero category="warning"><value name="exp">"heaPum.QCon_flow / heaPum.con.gai.k"</value>, <value name="val">"-NAN, 0.00000000000000E+00"</value></DivideByZero>
# [ERROR]   <NaNOutput category="error">Not a number in block <value name="rhs" flags="index">0</value> from <value name="block">"12"</value></NaNOutput>
# [ERROR]   <NaNOutput category="error">Not a number in block <value name="rhs" flags="index">0</value> from <value name="block">"13"</value></NaNOutput>
# [WARNING] <DivideByZero category="warning"><value name="exp">"weaDat.limRelHum.relHum * 0.621964713077499 / (0.621964713077499 * weaDat.limRelHum.relHum + weaDat.pAtmSel.p / (611.657 * exp(17.2799 - 4102.99 / (TOut.port.T - 35.719))) - weaDat.limRelHum.relHum)"</value>, <value name="val">"0.00000000000000E+00, 0.00000000000000E+00"</value></DivideByZero>
# [WARNING]   <IllegalResidualOutput category="warning">Not a number as output from <value name="block">"15"</value> with <value name="input">        2.9114999999999998E+02</value></IllegalResidualOutput>
# [WARNING]   <Warning category="warning">Residual function evaluation failed at initial point for <value name="block">"15"</value>, will try <value name="initial_guess">        0.0000000000000000E+00</value></Warning>
# [WARNING]   <IllegalResidualOutput category="warning">Not a number as output from <value name="block">"15"</value> with <value name="input">        0.0000000000000000E+00</value></IllegalResidualOutput>
# [WARNING]   <Warning category="warning">Residual function evaluation failed at initial point for <value name="block">"15"</value>, will try <value name="initial_guess">       1.7976931348623157E+308</value></Warning>
# [WARNING]   <IllegalIterationVariableInput category="warning">Absolute value of input too big in <value name="block">"15"</value></IllegalIterationVariableInput>
# [WARNING]   <Warning category="warning">Residual function evaluation failed at initial point for <value name="block">"15"</value>, will try <value name="initial_guess">        1.0000000000000000E+00</value></Warning>
# [WARNING]   <IllegalResidualOutput category="warning">Not a number as output from <value name="block">"15"</value> with <value name="input">        1.0000000000000000E+00</value></IllegalResidualOutput>
# [ERROR]   <Error category="error">Residual function evaluation failed at initial point for <value name="block">"15"</value> <value name="Iter">"#r999#"</value></Error>
# [WARNING] <AssertionError category="warning"><value name="msg">"Pressure (= -nan Pa) of medium ""Buildings.Media.Air"" is negative&##10;(Temperature = 357.084 K)"</value></AssertionError>
# [ERROR] <DerivativeCalculationFailure category="error">Evaluating the ode derivatives failed.</DerivativeCalculationFailure>
# ---------------------------------------------------------------------------
# FMICallException                          Traceback (most recent call last)
# Cell In [14], line 5
#       3 steps = 288*10
#       4 out_list = []
# ----> 5 env.reset()
#       6 env.step(env.sample_random_action())
#       7 outputs = env.get_output()
#
# File ~/energym/energym/envs/env_fmu_mod.py:198, in EnvModFMU.reset(self)
#     197 def reset(self):
# --> 198     super().reset()
#     199     self.set_model_variables(list(self.params.keys()), list(self.params.values()))
#     200     self.set_model_variables(
#     201         list(self.init_vals.keys()), list(self.init_vals.values())
#     202     )
#
# File ~/energym/energym/envs/env_fmu.py:695, in EnvFMU.reset(self)
#     693 def reset(self):
#     694     """Resets the simulation."""
# --> 695     self.close()
#     696     self.kpis.reset()
#     697     self.initialize()
#
# File ~/energym/energym/envs/env_fmu.py:702, in EnvFMU.close(self, save)
#     700 """Terminates the FMU and removes leftover folders."""
#     701 instance_name = self.fmu.instanceName
# --> 702 self.fmu.terminate()
#     703 self.fmu.freeInstance()
#     704 self.is_fmu_initialized = False
#
# File /anaconda/envs/env39/lib/python3.9/site-packages/fmpy/fmi2.py:283, in _FMU2.terminate(self)
#     282 def terminate(self):
# --> 283     return self.fmi2Terminate(self.component)
#
# File /anaconda/envs/env39/lib/python3.9/site-packages/fmpy/fmi2.py:215, in _FMU2._fmi2Function.<locals>.w(*args)
#     212 if restype == fmi2Status:  # status code
#     213     # check the status code
#     214     if res > fmi2Warning:
# --> 215         raise FMICallException(function=fname, status=res)
#     217 return res
#
# FMICallException: fmi2Terminate failed with status 3 (error).

# %% [markdown]
# Since the outputs are given as dictionaries and are collected in lists, we can simply load them as a pandas.DataFrame.

# %%
import pandas as pd
out_df = pd.DataFrame(out_list)

# %%
out_df
# Out:
#           TOut.T  heaPum.COP  heaPum.COPCar  heaPum.P  heaPum.QCon_flow  \
# 0     273.040697    3.534267       7.437804    5000.0      1.767134e+04
# 1     273.050842    3.534640       7.438588    5000.0      1.767320e+04
# 2     273.060017    3.533138       7.435427    5000.0      1.766569e+04
# 3     273.067805    3.529085       7.426898    5000.0      1.764542e+04
# 4     273.073788    3.523458       7.415057    5000.0      1.761729e+04
# ...          ...         ...            ...       ...               ...
# 2875  278.540000    3.641308       7.663069       0.0      2.938736e-39
# 2876  278.540000    3.641308       7.663069       0.0      2.938736e-39
# 2877  278.540000    3.641308       7.663069       0.0      2.938736e-39
# 2878  278.540000    3.641308       7.663069       0.0      2.938736e-39
# 2879  278.540000    3.641308       7.663069       0.0      2.938736e-39
#
#       heaPum.QEva_flow  heaPum.TConAct  heaPum.TEvaAct  preHea.Q_flow  \
# 0        -1.267134e+04      321.988855      278.698008            0.0
# 1        -1.267320e+04      321.988496      278.702258            0.0
# 2        -1.266569e+04      322.012420      278.704562            0.0
# 3        -1.264542e+04      322.077806      278.711408            0.0
# 4        -1.261729e+04      322.169078      278.721120            0.0
# ...                ...             ...             ...            ...
# 2875     -2.938736e-39      325.645431      283.150000            0.0
# 2876     -2.938736e-39      325.645431      283.150000            0.0
# 2877     -2.938736e-39      325.645431      283.150000            0.0
# 2878     -2.938736e-39      325.645431      283.150000            0.0
# 2879     -2.938736e-39      325.645431      283.150000            0.0
#
#         rad.Q_flow  ...  sunRad.y    temRet.T    temRoo.T    temSup.T  \
# 0    -17920.641869  ...       0.0  316.440754  293.390546  320.572635
# 1    -17681.274614  ...       0.0  316.348049  293.612518  320.574636
# 2    -17516.873945  ...       0.0  316.379873  293.825719  320.599010
# 3    -17396.958556  ...       0.0  316.455622  294.031841  320.665911
# 4    -17306.466774  ...       0.0  316.558271  294.232023  320.759368
# ...            ...  ...       ...         ...         ...         ...
# 2875   -840.836943  ...       0.0  321.767667  297.376703  325.645078
# 2876   -801.415264  ...       0.0  321.767667  297.126142  325.645078
# 2877   -768.236565  ...       0.0  321.767667  296.878177  325.645078
# 2878   -739.999966  ...       0.0  321.767667  296.632933  325.645078
# 2879   -715.695515  ...       0.0  321.767667  296.390500  325.645078
#
#       weaBus.HDifHor  weaBus.HDirNor  weaBus.HGloHor  weaBus.HHorIR  \
# 0                0.0             0.0             0.0     198.356554
# 1                0.0             0.0             0.0     198.314931
# 2                0.0             0.0             0.0     198.276953
# 3                0.0             0.0             0.0     198.244444
# 4                0.0             0.0             0.0     198.219227
# ...              ...             ...             ...            ...
# 2875             0.0             0.0             0.0     236.600000
# 2876             0.0             0.0             0.0     236.962500
# 2877             0.0             0.0             0.0     237.325000
# 2878             0.0             0.0             0.0     237.687500
# 2879             0.0             0.0             0.0     238.050000
#
#                y      time
# 0     293.390546     300.0
# 1     293.612518     600.0
# 2     293.825719     900.0
# 3     294.031841    1200.0
# 4     294.232023    1500.0
# ...          ...       ...
# 2875  297.376703  862800.0
# 2876  297.126142  863100.0
# 2877  296.878177  863400.0
# 2878  296.632933  863700.0
# 2879  296.390500  864000.0
#
# [2880 rows x 22 columns]

# %% [markdown]
# To generate plots, we can directly get the data from the DataFrames, by using the key names. Displayed are the room temperature, the supply temperature and the return temperature, as well as the external temperature, and the heat pump energy.

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

f, (ax1,ax2,ax3) = plt.subplots(3,figsize=(10,15))#


ax1.plot(out_df['temRoo.T']-273.15, 'r')
ax1.plot(out_df['temSup.T']-273.15, 'b--')
ax1.plot(out_df['temRet.T']-273.15, 'orange')
ax1.set_ylabel('Temp')
ax1.set_xlabel('Steps')

ax2.plot(out_df['TOut.T']-273.15, 'r')
ax2.set_ylabel('Temp')
ax2.set_xlabel('Steps')

ax3.plot(out_df['heaPum.QCon_flow'], 'g')
ax3.set_ylabel('Energy')
ax3.set_xlabel('Steps')

plt.subplots_adjust(hspace=0.4)

plt.show()
# Out:
# <div id='f1db8ce5-53ec-403c-9f4f-764853c79985'></div>

# %% [markdown]
# To end the simulation, the `close()` method is called. It deletes files that were produced during the simulation and stores some information about the simulation in the *energym_runs* folder.

# %%
env.close()
